# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\QFAI PC 1\Desktop\Personal Projects\thesis\TS_benchmark\simulation_results_sda\noisy_patch_results_full.csv")

# %%
df.groupby(['Model', 'Patch Length', 'Horizon',])[['RMSE', 'MAE']].mean()
# Out:
#                                    RMSE       MAE
# Model    Patch Length Horizon
# Full     4            4        0.061403  0.049273
#                       8        0.071575  0.057623
#          8            4        0.059333  0.047947
#                       8        0.067001  0.054937
#          12           4        0.061968  0.051059
#                       8        0.064637  0.053140
# Minimal  4            4        0.061792  0.049856
#                       8        0.065733  0.052326
#          8            4        0.060129  0.048422
#                       8        0.061534  0.049945
#          12           4        0.062485  0.050432
#                       8        0.062101  0.050243
# Standard 4            4        0.061204  0.048771
#                       8        0.063700  0.051293
#          8            4        0.056514  0.046040
#                       8        0.061869  0.050630
#          12           4        0.061874  0.050663
# ...
